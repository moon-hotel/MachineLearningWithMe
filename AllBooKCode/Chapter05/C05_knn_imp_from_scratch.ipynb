# %% [markdown]
# ## 1.载入数据集

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KDTree
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
import numpy as np
import logging
import sys


def load_data():
    x, y = load_iris(return_X_y=True)
    x_train, x_test, y_train, y_test = train_test_split(x, y,
                                                        test_size=0.3, random_state=20)
    return x_train, x_test, y_train, y_test

# %% [markdown]
# ## 2.定义节点

# %%
class Node(object):
    """
    定义KD树中的节点信息
    """

    def __init__(self, data=None, index=-1):
        self.data = data
        self.left_child = None
        self.right_child = None
        self.index = index

    def __str__(self):
        """
        打印节点信息
        :return:
        """
        return f"data({self.data}),index({int(self.index)})"

node = Node(np.array([1,2]), 0)
print(node)
# Out:
# data([1 2]),index(0)

# %% [markdown]
# ## 3.定义LP距离

# %%
def distance(p1, p2, p=2):
    """

    :param p1:
    :param p2:
    :param p:  当p=2时为欧式距离
    :return:
    """
    return np.sum((p1 - p2) ** p) ** (1 / p)

# %% [markdown]
# ## 4.定义KD树

# %%
class MyKDTree(object):
    """
    定义MyKDTree
    Parameters:
        points: 构造KD树用到的样本点，必须为np.array()类型，形状为 [n,m]
        p: p=2时为欧式距离
    """

    def __init__(self, points, p=2):
        self.root = None
        self.p = p
        self.dim = points.shape[1]
        self.distance = distance
        # 在原始样本的最后一列加入一列索引，表示每个样本点的序号
        points = np.hstack(([points, np.arange(0, len(points)).reshape(-1, 1)]))
        self.insert(points, order=0)  # 递归构建KD树

    def is_empty(self):
        return not self.root

    def level_order(self):
        """
        层次遍历
        :return:
        """
        root = self.root
        if not root:
            return []
        queue = [root]
        res = []
        while queue:
            tmp = []
            for i in range(len(queue)):
                node = queue.pop(0)
                tmp.append(node)
                if node.left_child:
                    queue.append(node.left_child)
                if node.right_child:
                    queue.append(node.right_child)
            res.append(tmp)
        print("\n层次遍历结果为：")
        for i, r in enumerate(res):
            print(f"第{i + 1}层的节点为：")
            for node in r:
                print(f"<p({node.data}), idx({int(node.index)})>")
            print("\n")
            
    def insert(self, data, order=0):
        """
        在KD树中插入节点
        :param data: 必须为np.array()类型，形状为 [n,m]
        :param order: 用来判断比较的维度
        :return:
        """
        if len(data) < 1:
            return
        data = sorted(data, key=lambda x: x[order % self.dim])  # 按某个维度进行排序
        print(f"当前待划分样本点：{[item.tolist() for item in data]}")
        idx = len(data) // 2
        node = Node(data[idx][:-1], data[idx][-1])
        print(f"父节点：{data[idx]}")
        left_data = data[:idx]
        print(f"左子树: {[item.tolist() for item in left_data]}")
        right_data = data[idx + 1:]
        print(f"右子树: {[item.tolist() for item in right_data]}")
        print("============")
        if self.is_empty():
            self.root = node  # 整个KD树的根节点
        node.left_child = self.insert(left_data, order + 1)  # 递归构建左子树
        node.right_child = self.insert(right_data, order + 1)  # 递归构建右子树
        return node

    def nearest_search(self, point):
        """
        最近邻搜索
        :param point: 必须为np.array()类型
        :return:
        """
        best_node = None
        best_dist = np.inf
        visited = []  # 用来记录哪些节点被访问过
        point = point.reshape(-1)

        def nearest_node_search(point, curr_node, order=0):
            """
            :param point:  shape: (n,)
            :param curr_node: data: shape (n,)
            :param order:
            :return:
            """
            nonlocal best_node, best_dist, visited  # 声明这三个变量不是局部变量
            print(f"当前访问节点为：{curr_node}")
            if curr_node is None:
                print(f"结束本次递归")
                return None
            visited.append(curr_node)
            dist = self.distance(curr_node.data, point, self.p)
            print(f"当前访问节点到被搜索点的距离为：{round(dist, 3)}")
            print(f"【上次】:全局最佳距离为：{round(best_dist, 3)}, 全局最佳点为：{best_node}")
            if dist < best_dist:
                best_dist = dist
                best_node = curr_node
            print(f"【本次】:全局最佳距离为：{round(best_dist, 3)}, 全局最佳点为：{best_node}\n")
            cmp_dim = order % self.dim
            if point[cmp_dim] < curr_node.data[cmp_dim]:
                print(f"访问当前节点{curr_node}的左孩子")
                nearest_node_search(point, curr_node.left_child, order + 1)
            else:
                print(f"访问当前节点{curr_node}的右孩子")
                nearest_node_search(point, curr_node.right_child, order + 1)
            print(f"回到上一层递归，当前访问节点为: {curr_node}，开始判断步骤(6)")
            if np.abs(curr_node.data[cmp_dim] - point[cmp_dim]) < best_dist:
                print(f"** {curr_node.data}满足条件被搜索点到当前节点划分维度的距离小于全局最短距离，即 "
                             f"|{curr_node.data[cmp_dim]} - {point[cmp_dim]}| < {round(best_dist, 3)} **")
                child = curr_node.left_child if curr_node.left_child not in visited else curr_node.right_child
                tmp = '左' if curr_node.left_child not in visited else '右'
                print(f"访问当前节点{curr_node}的{tmp}孩子")
                nearest_node_search(point, child, order + 1)

        nearest_node_search(point, self.root, 0)
        return best_node, best_dist

    def append(self, k_nearest_nodes, curr_node, point):
        """
        将当前节点加入到k_nearest_nodes中并按每个节点到被搜索点的距离升序排列
        :param k_nearest_nodes: list，用来保存到目前位置距离被搜索点最近的K个点
        :param curr_node:  Node()类型，当前访问的节点
        :param point: 被搜索点，np.array()类型，形状为(m,)
        :return:
        """
        k_nearest_nodes.append(curr_node)
        k_nearest_nodes = sorted(k_nearest_nodes,
                                 key=lambda x: self.distance(x.data, point, self.p))
        print(f"\t\t当前K近邻有序列表中的节点为（已按距离升序排序）：")
        for item in k_nearest_nodes:
            print(f"\t\t\t{item}", )
        print("\n")
        return k_nearest_nodes


    def k_nearest_search(self, points, k):
        """
        分别查找points中每个样本距其最近的k个样本点
        :param points: np.array()   形状为[n,m]
        :param k:
        :return:
        """
        result_points = []
        result_ind = []
        for point in points:
            k_nodes = self._k_nearest_search(point, k)
            tmp_points = []
            tmp_ind = []
            for node in k_nodes:
                tmp_points.append(node.data)
                tmp_ind.append(int(node.index))
            result_points.append(tmp_points)
            result_ind.append(tmp_ind)
        return np.array(result_points), np.array(result_ind)

    def _k_nearest_search(self, point, k):
        """
        寻找距离样本点point最近的k个样本点
        :param point: np.array()   形状为[m,]
        :param k:
        :return:
        """
        k_nearest_nodes = []
        visited = []
        n = 0
        print(f"\n\n=========== 正在查找离样本点{point}最近的{k}个样本点！==========\n")

        def k_nearest_node_search(point, curr_node, order=0):
            nonlocal k_nearest_nodes, n
            print(f"K近邻搜索当前访问节点为：{curr_node}")
            if curr_node is None:
                return None
            visited.append(curr_node)
            if n < k:  # 如果当前还没找到k个点，则直接进行保存
                print(f"\t有序列表中的节点数目为：{n} < {k}，直接加入新节点并排序")
                n += 1
                k_nearest_nodes = self.append(k_nearest_nodes, curr_node, point)
            else:  # 已经找到k个局部最优点，开始进行筛选
                d1 = self.distance(curr_node.data, point, self.p)
                d2 = self.distance(point, k_nearest_nodes[-1].data, self.p)
                print(f"\t被搜索点{point}到当前节点{curr_node}的距离为 {round(d1, 3)}")
                print(f"\t被搜索点{point}到列表中最后一个节点{k_nearest_nodes[-1]}的距离为 {round(d2, 3)}")
                if d1 < d2:
                    print(
                        f"\t当前节点到被搜索点的距离{round(d1, 3)} < 被搜索点到列表中最后一个节点的距离{round(d2, 3)}，进行替换")
                    k_nearest_nodes.pop()  # 移除最后一个
                    k_nearest_nodes = self.append(k_nearest_nodes, curr_node, point)  # 加入新的点并进行排序
            cmp_dim = order % self.dim
            if point[cmp_dim] < curr_node.data[cmp_dim]:
                print(f"访问当前节点{curr_node}的左孩子")
                k_nearest_node_search(point, curr_node.left_child, order + 1)
            else:
                print(f"访问当前节点{curr_node}的右孩子")
                k_nearest_node_search(point, curr_node.right_child, order + 1)
            print(f"回到上一层递归，当前访问节点为 {curr_node}，开始判断步骤(6)")
            if n < k or np.abs(curr_node.data[cmp_dim] - point[cmp_dim]) < \
                    self.distance(point, k_nearest_nodes[-1].data, self.p):
                print(
                    f"** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 "
                    f"|{curr_node.data[cmp_dim]} - {point[cmp_dim]}| < "
                    f"{round(self.distance(point, k_nearest_nodes[-1].data, self.p), 3)} **")
                child = curr_node.left_child if curr_node.left_child not in visited else curr_node.right_child
                tmp = '左' if curr_node.left_child not in visited else '右'
                print(f"访问当前节点{curr_node}的{tmp}孩子")
                k_nearest_node_search(point, child, order + 1)

        k_nearest_node_search(point, self.root, 0)
        return k_nearest_nodes

# %% [markdown]
# ## 5 运行结果

# %% [markdown]
# ### 5.1 构建KD树

# %%
points = np.array(
        [[5, 7], [3, 8], [6, 3], [8, 5], [15, 6.], [10, 4], [12, 13], [9, 10], [11, 14]])

def test_kd_tree_build(points):
    print("MyKDTree 运行结果：")
    print("构建KD树")
    tree = MyKDTree(points)
    print("构建结束")
    print("MyKDTree 层次遍历结果：")
    tree.level_order()

test_kd_tree_build(points)
# Out:
# MyKDTree 运行结果：
# 构建KD树
# 当前待划分样本点：[[3.0, 8.0, 1.0], [5.0, 7.0, 0.0], [6.0, 3.0, 2.0], [8.0, 5.0, 3.0], [9.0, 10.0, 7.0], [10.0, 4.0, 5.0], [11.0, 14.0, 8.0], [12.0, 13.0, 6.0], [15.0, 6.0, 4.0]]
# 父节点：[ 9. 10.  7.]
# 左子树: [[3.0, 8.0, 1.0], [5.0, 7.0, 0.0], [6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 右子树: [[10.0, 4.0, 5.0], [11.0, 14.0, 8.0], [12.0, 13.0, 6.0], [15.0, 6.0, 4.0]]
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0], [8.0, 5.0, 3.0], [5.0, 7.0, 0.0], [3.0, 8.0, 1.0]]
# 父节点：[5. 7. 0.]
# 左子树: [[6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 右子树: [[3.0, 8.0, 1.0]]
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 父节点：[8. 5. 3.]
# 左子树: [[6.0, 3.0, 2.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0]]
# 父节点：[6. 3. 2.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[3.0, 8.0, 1.0]]
# 父节点：[3. 8. 1.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0], [15.0, 6.0, 4.0], [12.0, 13.0, 6.0], [11.0, 14.0, 8.0]]
# 父节点：[12. 13.  6.]
# 左子树: [[10.0, 4.0, 5.0], [15.0, 6.0, 4.0]]
# 右子树: [[11.0, 14.0, 8.0]]
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0], [15.0, 6.0, 4.0]]
# 父节点：[15.  6.  4.]
# 左子树: [[10.0, 4.0, 5.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0]]
# 父节点：[10.  4.  5.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[11.0, 14.0, 8.0]]
# 父节点：[11. 14.  8.]
# 左子树: []
# 右子树: []
# ============
# 构建结束
# MyKDTree 层次遍历结果：
#
# 层次遍历结果为：
# 第1层的节点为：
# <p([ 9. 10.]), idx(7)>
#
#
# 第2层的节点为：
# <p([5. 7.]), idx(0)>
# <p([12. 13.]), idx(6)>
#
#
# 第3层的节点为：
# <p([8. 5.]), idx(3)>
# <p([3. 8.]), idx(1)>
# <p([15.  6.]), idx(4)>
# <p([11. 14.]), idx(8)>
#
#
# 第4层的节点为：
# <p([6. 3.]), idx(2)>
# <p([10.  4.]), idx(5)>

# %% [markdown]
# ### 5.2 KD树最近邻搜索

# %%
def test_kd_nearest_search(points, q=None):
    tree = MyKDTree(points)
    best_node, best_dist = tree.nearest_search(q)
    print("MyKDTree 运行结果：")
    print(f"离样本点{q}最近的节点是：{best_node},距离为：{round(best_dist, 3)}")

    kd_tree = KDTree(points)
    dist, ind = kd_tree.query(q, k=1)
    print("sklearn KDTree 运行结果：")
    print(f"离样本点{q}最近的节点是：{points[ind]},距离为：{dist}")

test_kd_nearest_search(points, q=np.array([[8.9, 4]]))
# Out:
# 当前待划分样本点：[[3.0, 8.0, 1.0], [5.0, 7.0, 0.0], [6.0, 3.0, 2.0], [8.0, 5.0, 3.0], [9.0, 10.0, 7.0], [10.0, 4.0, 5.0], [11.0, 14.0, 8.0], [12.0, 13.0, 6.0], [15.0, 6.0, 4.0]]
# 父节点：[ 9. 10.  7.]
# 左子树: [[3.0, 8.0, 1.0], [5.0, 7.0, 0.0], [6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 右子树: [[10.0, 4.0, 5.0], [11.0, 14.0, 8.0], [12.0, 13.0, 6.0], [15.0, 6.0, 4.0]]
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0], [8.0, 5.0, 3.0], [5.0, 7.0, 0.0], [3.0, 8.0, 1.0]]
# 父节点：[5. 7. 0.]
# 左子树: [[6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 右子树: [[3.0, 8.0, 1.0]]
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 父节点：[8. 5. 3.]
# 左子树: [[6.0, 3.0, 2.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0]]
# 父节点：[6. 3. 2.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[3.0, 8.0, 1.0]]
# 父节点：[3. 8. 1.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0], [15.0, 6.0, 4.0], [12.0, 13.0, 6.0], [11.0, 14.0, 8.0]]
# 父节点：[12. 13.  6.]
# 左子树: [[10.0, 4.0, 5.0], [15.0, 6.0, 4.0]]
# 右子树: [[11.0, 14.0, 8.0]]
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0], [15.0, 6.0, 4.0]]
# 父节点：[15.  6.  4.]
# 左子树: [[10.0, 4.0, 5.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0]]
# 父节点：[10.  4.  5.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[11.0, 14.0, 8.0]]
# 父节点：[11. 14.  8.]
# 左子树: []
# 右子树: []
# ============
# 当前访问节点为：data([ 9. 10.]),index(7)
# 当前访问节点到被搜索点的距离为：6.001
# 【上次】:全局最佳距离为：inf, 全局最佳点为：None
# 【本次】:全局最佳距离为：6.001, 全局最佳点为：data([ 9. 10.]),index(7)
#
# 访问当前节点data([ 9. 10.]),index(7)的左孩子
# 当前访问节点为：data([5. 7.]),index(0)
# 当前访问节点到被搜索点的距离为：4.92
# 【上次】:全局最佳距离为：6.001, 全局最佳点为：data([ 9. 10.]),index(7)
# 【本次】:全局最佳距离为：4.92, 全局最佳点为：data([5. 7.]),index(0)
#
# 访问当前节点data([5. 7.]),index(0)的左孩子
# 当前访问节点为：data([8. 5.]),index(3)
# 当前访问节点到被搜索点的距离为：1.345
# 【上次】:全局最佳距离为：4.92, 全局最佳点为：data([5. 7.]),index(0)
# 【本次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
#
# 访问当前节点data([8. 5.]),index(3)的右孩子
# 当前访问节点为：None
# 结束本次递归
# 回到上一层递归，当前访问节点为: data([8. 5.]),index(3)，开始判断步骤(6)
# ** [8. 5.]满足条件被搜索点到当前节点划分维度的距离小于全局最短距离，即 |8.0 - 8.9| < 1.345 **
# 访问当前节点data([8. 5.]),index(3)的左孩子
# 当前访问节点为：data([6. 3.]),index(2)
# 当前访问节点到被搜索点的距离为：3.068
# 【上次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
# 【本次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
#
# 访问当前节点data([6. 3.]),index(2)的右孩子
# 当前访问节点为：None
# 结束本次递归
# 回到上一层递归，当前访问节点为: data([6. 3.]),index(2)，开始判断步骤(6)
# ** [6. 3.]满足条件被搜索点到当前节点划分维度的距离小于全局最短距离，即 |3.0 - 4.0| < 1.345 **
# 访问当前节点data([6. 3.]),index(2)的左孩子
# 当前访问节点为：None
# 结束本次递归
# 回到上一层递归，当前访问节点为: data([5. 7.]),index(0)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为: data([ 9. 10.]),index(7)，开始判断步骤(6)
# ** [ 9. 10.]满足条件被搜索点到当前节点划分维度的距离小于全局最短距离，即 |9.0 - 8.9| < 1.345 **
# 访问当前节点data([ 9. 10.]),index(7)的右孩子
# 当前访问节点为：data([12. 13.]),index(6)
# 当前访问节点到被搜索点的距离为：9.519
# 【上次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
# 【本次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
#
# 访问当前节点data([12. 13.]),index(6)的左孩子
# 当前访问节点为：data([15.  6.]),index(4)
# 当前访问节点到被搜索点的距离为：6.42
# 【上次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
# 【本次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
#
# 访问当前节点data([15.  6.]),index(4)的左孩子
# 当前访问节点为：data([10.  4.]),index(5)
# 当前访问节点到被搜索点的距离为：1.1
# 【上次】:全局最佳距离为：1.345, 全局最佳点为：data([8. 5.]),index(3)
# 【本次】:全局最佳距离为：1.1, 全局最佳点为：data([10.  4.]),index(5)
#
# 访问当前节点data([10.  4.]),index(5)的右孩子
# 当前访问节点为：None
# 结束本次递归
# 回到上一层递归，当前访问节点为: data([10.  4.]),index(5)，开始判断步骤(6)
# ** [10.  4.]满足条件被搜索点到当前节点划分维度的距离小于全局最短距离，即 |4.0 - 4.0| < 1.1 **
# 访问当前节点data([10.  4.]),index(5)的左孩子
# 当前访问节点为：None
# 结束本次递归
# 回到上一层递归，当前访问节点为: data([15.  6.]),index(4)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为: data([12. 13.]),index(6)，开始判断步骤(6)
# MyKDTree 运行结果：
# 离样本点[[8.9 4. ]]最近的节点是：data([10.  4.]),index(5),距离为：1.1
# sklearn KDTree 运行结果：
# 离样本点[[8.9 4. ]]最近的节点是：[[[10.  4.]]],距离为：[[1.1]]

# %% [markdown]
# ### 5.3 KD树K近邻搜索

# %%
def test_kd_k_nearest_search():
    points = np.array(
        [[5, 7], [3, 8], [6, 3], [8, 5], [15, 6.], [10, 4], [12, 13], [9, 10], [11, 14]])
    tree = MyKDTree(points)
    p = np.array([[8.9, 4]])
    k_best_nodes, ind = tree.k_nearest_search(p, k=3)
    print("MyKDTree 运行结果：")
    print(f"\n{k_best_nodes}")
    print(f"样本索引编号为:{ind}")

    print("sklearn KDTree 运行结果：")
    kd_tree = KDTree(points)
    dist, ind = kd_tree.query(p, k=3)
    print(f"\n{points[ind]}", )
    print(f"样本索引编号为:{ind}")
test_kd_k_nearest_search()
# Out:
# 当前待划分样本点：[[3.0, 8.0, 1.0], [5.0, 7.0, 0.0], [6.0, 3.0, 2.0], [8.0, 5.0, 3.0], [9.0, 10.0, 7.0], [10.0, 4.0, 5.0], [11.0, 14.0, 8.0], [12.0, 13.0, 6.0], [15.0, 6.0, 4.0]]
# 父节点：[ 9. 10.  7.]
# 左子树: [[3.0, 8.0, 1.0], [5.0, 7.0, 0.0], [6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 右子树: [[10.0, 4.0, 5.0], [11.0, 14.0, 8.0], [12.0, 13.0, 6.0], [15.0, 6.0, 4.0]]
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0], [8.0, 5.0, 3.0], [5.0, 7.0, 0.0], [3.0, 8.0, 1.0]]
# 父节点：[5. 7. 0.]
# 左子树: [[6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 右子树: [[3.0, 8.0, 1.0]]
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0], [8.0, 5.0, 3.0]]
# 父节点：[8. 5. 3.]
# 左子树: [[6.0, 3.0, 2.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.0, 3.0, 2.0]]
# 父节点：[6. 3. 2.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[3.0, 8.0, 1.0]]
# 父节点：[3. 8. 1.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0], [15.0, 6.0, 4.0], [12.0, 13.0, 6.0], [11.0, 14.0, 8.0]]
# 父节点：[12. 13.  6.]
# 左子树: [[10.0, 4.0, 5.0], [15.0, 6.0, 4.0]]
# 右子树: [[11.0, 14.0, 8.0]]
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0], [15.0, 6.0, 4.0]]
# 父节点：[15.  6.  4.]
# 左子树: [[10.0, 4.0, 5.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[10.0, 4.0, 5.0]]
# 父节点：[10.  4.  5.]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[11.0, 14.0, 8.0]]
# 父节点：[11. 14.  8.]
# 左子树: []
# 右子树: []
# ============
#
#
# =========== 正在查找离样本点[8.9 4. ]最近的3个样本点！==========
#
# K近邻搜索当前访问节点为：data([ 9. 10.]),index(7)
# 	有序列表中的节点数目为：0 < 3，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([ 9. 10.]),index(7)
#
#
# 访问当前节点data([ 9. 10.]),index(7)的左孩子
# K近邻搜索当前访问节点为：data([5. 7.]),index(0)
# 	有序列表中的节点数目为：1 < 3，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([5. 7.]),index(0)
# 			data([ 9. 10.]),index(7)
#
#
# 访问当前节点data([5. 7.]),index(0)的左孩子
# K近邻搜索当前访问节点为：data([8. 5.]),index(3)
# 	有序列表中的节点数目为：2 < 3，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([8. 5.]),index(3)
# 			data([5. 7.]),index(0)
# 			data([ 9. 10.]),index(7)
#
#
# 访问当前节点data([8. 5.]),index(3)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([8. 5.]),index(3)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |8.0 - 8.9| < 6.001 **
# 访问当前节点data([8. 5.]),index(3)的左孩子
# K近邻搜索当前访问节点为：data([6. 3.]),index(2)
# 	被搜索点[8.9 4. ]到当前节点data([6. 3.]),index(2)的距离为 3.068
# 	被搜索点[8.9 4. ]到列表中最后一个节点data([ 9. 10.]),index(7)的距离为 6.001
# 	当前节点到被搜索点的距离3.068 < 被搜索点到列表中最后一个节点的距离6.001，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([8. 5.]),index(3)
# 			data([6. 3.]),index(2)
# 			data([5. 7.]),index(0)
#
#
# 访问当前节点data([6. 3.]),index(2)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6. 3.]),index(2)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.0 - 4.0| < 4.92 **
# 访问当前节点data([6. 3.]),index(2)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5. 7.]),index(0)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |7.0 - 4.0| < 4.92 **
# 访问当前节点data([5. 7.]),index(0)的右孩子
# K近邻搜索当前访问节点为：data([3. 8.]),index(1)
# 	被搜索点[8.9 4. ]到当前节点data([3. 8.]),index(1)的距离为 7.128
# 	被搜索点[8.9 4. ]到列表中最后一个节点data([5. 7.]),index(0)的距离为 4.92
# 访问当前节点data([3. 8.]),index(1)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([3. 8.]),index(1)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([ 9. 10.]),index(7)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |9.0 - 8.9| < 4.92 **
# 访问当前节点data([ 9. 10.]),index(7)的右孩子
# K近邻搜索当前访问节点为：data([12. 13.]),index(6)
# 	被搜索点[8.9 4. ]到当前节点data([12. 13.]),index(6)的距离为 9.519
# 	被搜索点[8.9 4. ]到列表中最后一个节点data([5. 7.]),index(0)的距离为 4.92
# 访问当前节点data([12. 13.]),index(6)的左孩子
# K近邻搜索当前访问节点为：data([15.  6.]),index(4)
# 	被搜索点[8.9 4. ]到当前节点data([15.  6.]),index(4)的距离为 6.42
# 	被搜索点[8.9 4. ]到列表中最后一个节点data([5. 7.]),index(0)的距离为 4.92
# 访问当前节点data([15.  6.]),index(4)的左孩子
# K近邻搜索当前访问节点为：data([10.  4.]),index(5)
# 	被搜索点[8.9 4. ]到当前节点data([10.  4.]),index(5)的距离为 1.1
# 	被搜索点[8.9 4. ]到列表中最后一个节点data([5. 7.]),index(0)的距离为 4.92
# 	当前节点到被搜索点的距离1.1 < 被搜索点到列表中最后一个节点的距离4.92，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([10.  4.]),index(5)
# 			data([8. 5.]),index(3)
# 			data([6. 3.]),index(2)
#
#
# 访问当前节点data([10.  4.]),index(5)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([10.  4.]),index(5)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |4.0 - 4.0| < 3.068 **
# 访问当前节点data([10.  4.]),index(5)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([15.  6.]),index(4)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([12. 13.]),index(6)，开始判断步骤(6)

# %% [markdown]
# ## 6 KNN实现

# %%
class MyKNN():
    def __init__(self, n_neighbors, p=2):
        """
        :param n_neighbors:
        :param p: 当p=2时表示欧氏距离
        """
        self.n_neighbors = n_neighbors
        self.p = p

    def fit(self, x, y):
        self._y = y
        self.kd_tree = MyKDTree(x, self.p)
        return self

    @staticmethod
    def get_pred_labels(query_label):
        """
        根据query_label返回每个样本对应的标签
        :param query_label: 二维数组， query_label[i] 表示离第i个样本最近的k个样本点对应的正确标签
        :return:
        """
        y_pred = [0] * len(query_label)
        for i, label in enumerate(query_label):
            max_freq = 0
            count_dict = {}
            for l in label:
                count_dict[l] = count_dict.setdefault(l, 0) + 1
                if count_dict[l] > max_freq:
                    max_freq = count_dict[l]
                    y_pred[i] = l
        return np.array(y_pred)

    def predict(self, x):
        k_best_nodes, ind = self.kd_tree.k_nearest_search(x, k=self.n_neighbors)
        query_label = self._y[ind]
        y_pred = self.get_pred_labels(query_label)
        return y_pred

# %% [markdown]
# ## 7 测试对于结果

# %%
x_train, x_test, y_train, y_test = load_data()
k = 5
my_model = MyKNN(n_neighbors=k)
my_model.fit(x_train, y_train)
y_pred = my_model.predict(x_test)
print(f"impl_by_ours 准确率：{accuracy_score(y_test, y_pred)}")

model = KNeighborsClassifier(n_neighbors=k)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(f"impl_by_sklearn 准确率：{accuracy_score(y_test, y_pred)}")
# Out:
# 当前待划分样本点：[[4.4, 3.0, 1.3, 0.2, 25.0], [4.4, 2.9, 1.4, 0.2, 45.0], [4.4, 3.2, 1.3, 0.2, 56.0], [4.5, 2.3, 1.3, 0.3, 12.0], [4.6, 3.1, 1.5, 0.2, 78.0], [4.6, 3.4, 1.4, 0.3, 91.0], [4.6, 3.6, 1.0, 0.2, 100.0], [4.7,
# 父节点：[ 5.   3.   1.6  0.2 89. ]
# 左子树: [[4.9, 3.1, 1.5, 0.1, 24.0], [4.4, 3.0, 1.3, 0.2, 25.0], [4.4, 3.2, 1.3, 0.2, 56.0], [4.7, 3.2, 1.3, 0.2, 0.0], [4.4, 2.9, 1.4, 0.2, 45.0], [4.6, 3.1, 1.5, 0.2, 78.0]]
# 右子树: [[4.8, 3.1, 1.6, 0.2, 33.0], [4.5, 2.3, 1.3, 0.3, 12.0], [4.8, 3.0, 1.4, 0.3, 65.0], [5.0, 2.3, 3.3, 1.0, 59.0], [5.0, 2.0, 3.5, 1.0, 34.0], [5.7, 2.6, 3.5, 1.0, 71.0]]
# ============
# 当前待划分样本点：[[4.4, 3.0, 1.3, 0.2, 25.0], [4.4, 3.2, 1.3, 0.2, 56.0], [4.4, 2.9, 1.4, 0.2, 45.0], [4.6, 3.1, 1.5, 0.2, 78.0], [4.7, 3.2, 1.3, 0.2, 0.0], [4.9, 3.1, 1.5, 0.1, 24.0]]
# 父节点：[ 4.6  3.1  1.5  0.2 78. ]
# 左子树: [[4.4, 3.0, 1.3, 0.2, 25.0], [4.4, 3.2, 1.3, 0.2, 56.0], [4.4, 2.9, 1.4, 0.2, 45.0]]
# 右子树: [[4.7, 3.2, 1.3, 0.2, 0.0], [4.9, 3.1, 1.5, 0.1, 24.0]]
# ============
# 当前待划分样本点：[[4.4, 2.9, 1.4, 0.2, 45.0], [4.4, 3.0, 1.3, 0.2, 25.0], [4.4, 3.2, 1.3, 0.2, 56.0]]
# 父节点：[ 4.4  3.   1.3  0.2 25. ]
# 左子树: [[4.4, 2.9, 1.4, 0.2, 45.0]]
# 右子树: [[4.4, 3.2, 1.3, 0.2, 56.0]]
# ============
# 当前待划分样本点：[[4.4, 2.9, 1.4, 0.2, 45.0]]
# 父节点：[ 4.4  2.9  1.4  0.2 45. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[4.4, 3.2, 1.3, 0.2, 56.0]]
# 父节点：[ 4.4  3.2  1.3  0.2 56. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[4.9, 3.1, 1.5, 0.1, 24.0], [4.7, 3.2, 1.3, 0.2, 0.0]]
# 父节点：[4.7 3.2 1.3 0.2 0. ]
# 左子树: [[4.9, 3.1, 1.5, 0.1, 24.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[4.9, 3.1, 1.5, 0.1, 24.0]]
# 父节点：[ 4.9  3.1  1.5  0.1 24. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[4.5, 2.3, 1.3, 0.3, 12.0], [4.8, 3.1, 1.6, 0.2, 33.0], [4.8, 3.0, 1.4, 0.3, 65.0], [5.0, 2.3, 3.3, 1.0, 59.0], [5.0, 2.0, 3.5, 1.0, 34.0], [5.7, 2.6, 3.5, 1.0, 71.0]]
# 父节点：[ 5.   2.3  3.3  1.  59. ]
# 左子树: [[4.5, 2.3, 1.3, 0.3, 12.0], [4.8, 3.1, 1.6, 0.2, 33.0], [4.8, 3.0, 1.4, 0.3, 65.0]]
# 右子树: [[5.0, 2.0, 3.5, 1.0, 34.0], [5.7, 2.6, 3.5, 1.0, 71.0]]
# ============
# 当前待划分样本点：[[4.5, 2.3, 1.3, 0.3, 12.0], [4.8, 3.0, 1.4, 0.3, 65.0], [4.8, 3.1, 1.6, 0.2, 33.0]]
# 父节点：[ 4.8  3.   1.4  0.3 65. ]
# 左子树: [[4.5, 2.3, 1.3, 0.3, 12.0]]
# 右子树: [[4.8, 3.1, 1.6, 0.2, 33.0]]
# ============
# 当前待划分样本点：[[4.5, 2.3, 1.3, 0.3, 12.0]]
# 父节点：[ 4.5  2.3  1.3  0.3 12. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[4.8, 3.1, 1.6, 0.2, 33.0]]
# 父节点：[ 4.8  3.1  1.6  0.2 33. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.0, 2.0, 3.5, 1.0, 34.0], [5.7, 2.6, 3.5, 1.0, 71.0]]
# 父节点：[ 5.7  2.6  3.5  1.  71. ]
# 左子树: [[5.0, 2.0, 3.5, 1.0, 34.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.0, 2.0, 3.5, 1.0, 34.0]]
# 父节点：[ 5.   2.   3.5  1.  34. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.5, 2.4, 3.8, 1.1, 14.0], [5.6, 2.5, 3.9, 1.1, 17.0], [5.5, 2.6, 4.4, 1.2, 70.0], [5.5, 2.3, 4.0, 1.3, 27.0], [5.7, 2.8, 4.1, 1.3, 104.0], [5.6, 2.7, 4.2, 1.3, 55.0], [5.7, 2.9, 4.2, 1.3, 20.0], [5.2, 2.7, 3.9, 1.4, 69.0], [5.4, 3.0, 4.5, 1.5, 26.0], [5.6, 3.0, 4.5, 1.5, 11.0], [5.6, 2.8, 4.9, 2.0, 37.0], [5.7, 2.5, 5.0, 2.0, 3.0]]
# 父节点：[ 5.7  2.9  4.2  1.3 20. ]
# 左子树: [[5.5, 2.4, 3.8, 1.1, 14.0], [5.6, 2.5, 3.9, 1.1, 17.0], [5.5, 2.6, 4.4, 1.2, 70.0], [5.5, 2.3, 4.0, 1.3, 27.0], [5.7, 2.8, 4.1, 1.3, 104.0], [5.6, 2.7, 4.2, 1.3, 55.0]]
# 右子树: [[5.2, 2.7, 3.9, 1.4, 69.0], [5.4, 3.0, 4.5, 1.5, 26.0], [5.6, 3.0, 4.5, 1.5, 11.0], [5.6, 2.8, 4.9, 2.0, 37.0], [5.7, 2.5, 5.0, 2.0, 3.0]]
# ============
# 当前待划分样本点：[[5.5, 2.4, 3.8, 1.1, 14.0], [5.5, 2.6, 4.4, 1.2, 70.0], [5.5, 2.3, 4.0, 1.3, 27.0], [5.6, 2.5, 3.9, 1.1, 17.0], [5.6, 2.7, 4.2, 1.3, 55.0], [5.7, 2.8, 4.1, 1.3, 104.0]]
# 父节点：[ 5.6  2.5  3.9  1.1 17. ]
# 左子树: [[5.5, 2.4, 3.8, 1.1, 14.0], [5.5, 2.6, 4.4, 1.2, 70.0], [5.5, 2.3, 4.0, 1.3, 27.0]]
# 右子树: [[5.6, 2.7, 4.2, 1.3, 55.0], [5.7, 2.8, 4.1, 1.3, 104.0]]
# ============
# 当前待划分样本点：[[5.5, 2.3, 4.0, 1.3, 27.0], [5.5, 2.4, 3.8, 1.1, 14.0], [5.5, 2.6, 4.4, 1.2, 70.0]]
# 父节点：[ 5.5  2.4  3.8  1.1 14. ]
# 左子树: [[5.5, 2.3, 4.0, 1.3, 27.0]]
# 右子树: [[5.5, 2.6, 4.4, 1.2, 70.0]]
# ============
# 当前待划分样本点：[[5.5, 2.3, 4.0, 1.3, 27.0]]
# 父节点：[ 5.5  2.3  4.   1.3 27. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.5, 2.6, 4.4, 1.2, 70.0]]
# 父节点：[ 5.5  2.6  4.4  1.2 70. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.6, 2.7, 4.2, 1.3, 55.0], [5.7, 2.8, 4.1, 1.3, 104.0]]
# 父节点：[  5.7   2.8   4.1   1.3 104. ]
# 左子树: [[5.6, 2.7, 4.2, 1.3, 55.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.6, 2.7, 4.2, 1.3, 55.0]]
# 父节点：[ 5.6  2.7  4.2  1.3 55. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.2, 2.7, 3.9, 1.4, 69.0], [5.4, 3.0, 4.5, 1.5, 26.0], [5.6, 3.0, 4.5, 1.5, 11.0], [5.6, 2.8, 4.9, 2.0, 37.0], [5.7, 2.5, 5.0, 2.0, 3.0]]
# 父节点：[ 5.6  3.   4.5  1.5 11. ]
# 左子树: [[5.2, 2.7, 3.9, 1.4, 69.0], [5.4, 3.0, 4.5, 1.5, 26.0]]
# 右子树: [[5.6, 2.8, 4.9, 2.0, 37.0], [5.7, 2.5, 5.0, 2.0, 3.0]]
# ============
# 当前待划分样本点：[[5.2, 2.7, 3.9, 1.4, 69.0], [5.4, 3.0, 4.5, 1.5, 26.0]]
# 父节点：[ 5.4  3.   4.5  1.5 26. ]
# 左子树: [[5.2, 2.7, 3.9, 1.4, 69.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.2, 2.7, 3.9, 1.4, 69.0]]
# 父节点：[ 5.2  2.7  3.9  1.4 69. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.7, 2.5, 5.0, 2.0, 3.0], [5.6, 2.8, 4.9, 2.0, 37.0]]
# 父节点：[ 5.6  2.8  4.9  2.  37. ]
# 左子树: [[5.7, 2.5, 5.0, 2.0, 3.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.7, 2.5, 5.0, 2.0, 3.0]]
# 父节点：[5.7 2.5 5.  2.  3. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[4.6, 3.6, 1.0, 0.2, 100.0], [5.0, 3.5, 1.3, 0.3, 97.0], [5.5, 3.5, 1.3, 0.2, 32.0], [5.4, 3.9, 1.3, 0.4, 95.0], [5.0, 3.3, 1.4, 0.2, 2.0], [4.6, 3.4, 1.4, 0.3, 91.0], [5.1, 3.5, 1.4, 0.3, 76.0], [5.0, 3.6, 1.4, 0.2, 48.0], [5.5, 4.2, 1.4, 0.2, 58.0], [5.0, 3.4, 1.5, 0.2, 92.0], [5.1, 3.4, 1.5, 0.2, 13.0], [5.4, 3.4, 1.5, 0.4, 7.0], [5.2, 3.5, 1.5, 0.2, 47.0], [5.3, 3.7, 1.5, 0.2, 30.0], [5.4, 3.7, 1.5, 0.2, 83.0], [5.1, 3.8, 1.5, 0.3, 29.0], [5.2, 4.1, 1.5, 0.1, 84.0], [5.7, 4.4, 1.5, 0.4, 103.0], [5.0, 3.4, 1.6, 0.4, 96.0], [5.0, 3.5, 1.6, 0.6, 74.0], [5.1, 3.3, 1.7, 0.5, 21.0], [5.7, 3.8, 1.7, 0.3, 79.0], [5.4, 3.9, 1.7, 0.4, 1.0], [4.8, 3.4, 1.9, 0.2, 61.0], [5.1, 3.8, 1.9, 0.4, 4.0]]
# 父节点：[ 5.   3.4  1.5  0.2 92. ]
# 左子树: [[4.6, 3.6, 1.0, 0.2, 100.0], [5.0, 3.3, 1.4, 0.2, 2.0], [5.0, 3.6, 1.4, 0.2, 48.0]]
# 右子树: [[5.5, 3.5, 1.3, 0.2, 32.0], [5.5, 4.2, 1.4, 0.2, 58.0]]
# ============
# 当前待划分样本点：[[5.0, 3.3, 1.4, 0.2, 2.0], [4.6, 3.6, 1.0, 0.2, 100.0], [5.0, 3.6, 1.4, 0.2, 48.0]]
# 父节点：[  4.6   3.6   1.    0.2 100. ]
# 左子树: [[5.0, 3.3, 1.4, 0.2, 2.0]]
# 右子树: [[5.0, 3.6, 1.4, 0.2, 48.0]]
# ============
# 当前待划分样本点：[[5.0, 3.3, 1.4, 0.2, 2.0]]
# 父节点：[5.  3.3 1.4 0.2 2. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.0, 3.6, 1.4, 0.2, 48.0]]
# 父节点：[ 5.   3.6  1.4  0.2 48. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.5, 3.5, 1.3, 0.2, 32.0], [5.5, 4.2, 1.4, 0.2, 58.0]]
# 父节点：[ 5.5  4.2  1.4  0.2 58. ]
# 左子树: [[5.5, 3.5, 1.3, 0.2, 32.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.5, 3.5, 1.3, 0.2, 32.0]]
# 父节点：[ 5.5  3.5  1.3  0.2 32. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[4.6, 3.4, 1.4, 0.3, 91.0], [5.0, 3.5, 1.3, 0.3, 97.0], [5.1, 3.5, 1.4, 0.3, 76.0], [5.4, 3.9, 1.3, 0.4, 95.0], [5.4, 3.4, 1.5, 0.4, 7.0]]
# 父节点：[ 5.1  3.5  1.4  0.3 76. ]
# 左子树: [[4.6, 3.4, 1.4, 0.3, 91.0], [5.0, 3.5, 1.3, 0.3, 97.0]]
# 右子树: [[5.4, 3.9, 1.3, 0.4, 95.0], [5.4, 3.4, 1.5, 0.4, 7.0]]
# ============
# 当前待划分样本点：[[4.6, 3.4, 1.4, 0.3, 91.0], [5.0, 3.5, 1.3, 0.3, 97.0]]
# 父节点：[ 5.   3.5  1.3  0.3 97. ]
# 左子树: [[4.6, 3.4, 1.4, 0.3, 91.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[4.6, 3.4, 1.4, 0.3, 91.0]]
# 父节点：[ 4.6  3.4  1.4  0.3 91. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.4, 3.4, 1.5, 0.4, 7.0], [5.4, 3.9, 1.3, 0.4, 95.0]]
# 父节点：[ 5.4  3.9  1.3  0.4 95. ]
# 左子树: [[5.4, 3.4, 1.5, 0.4, 7.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.4, 3.4, 1.5, 0.4, 7.0]]
# 父节点：[5.4 3.4 1.5 0.4 7. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.2, 4.1, 1.5, 0.1, 84.0], [5.3, 3.7, 1.5, 0.2, 30.0], [5.4, 3.7, 1.5, 0.2, 83.0], [4.8, 3.4, 1.9, 0.2, 61.0], [5.1, 3.8, 1.5, 0.3, 29.0], [5.7, 3.8, 1.7, 0.3, 79.0], [5.7, 4.4, 1.5, 0.4, 103.0], [5.0, 3.4, 1.6, 0.4, 96.0], [5.4, 3.9, 1.7, 0.4, 1.0], [5.1, 3.8, 1.9, 0.4, 4.0], [5.1, 3.3, 1.7, 0.5, 21.0], [5.0, 3.5, 1.6, 0.6, 74.0]]
# 父节点：[  5.7   4.4   1.5   0.4 103. ]
# 左子树: [[5.2, 4.1, 1.5, 0.1, 84.0], [5.3, 3.7, 1.5, 0.2, 30.0], [5.4, 3.7, 1.5, 0.2, 83.0], [4.8, 3.4, 1.9, 0.2, 61.0], [5.1, 3.8, 1.5, 0.3, 29.0], [5.7, 3.8, 1.7, 0.3, 79.0]]
# 右子树: [[5.0, 3.4, 1.6, 0.4, 96.0], [5.4, 3.9, 1.7, 0.4, 1.0], [5.1, 3.8, 1.9, 0.4, 4.0], [5.1, 3.3, 1.7, 0.5, 21.0], [5.0, 3.5, 1.6, 0.6, 74.0]]
# ============
# 当前待划分样本点：[[4.8, 3.4, 1.9, 0.2, 61.0], [5.1, 3.8, 1.5, 0.3, 29.0], [5.2, 4.1, 1.5, 0.1, 84.0], [5.3, 3.7, 1.5, 0.2, 30.0], [5.4, 3.7, 1.5, 0.2, 83.0], [5.7, 3.8, 1.7, 0.3, 79.0]]
# 父节点：[ 5.3  3.7  1.5  0.2 30. ]
# 左子树: [[4.8, 3.4, 1.9, 0.2, 61.0], [5.1, 3.8, 1.5, 0.3, 29.0], [5.2, 4.1, 1.5, 0.1, 84.0]]
# 右子树: [[5.4, 3.7, 1.5, 0.2, 83.0], [5.7, 3.8, 1.7, 0.3, 79.0]]
# ============
# 当前待划分样本点：[[4.8, 3.4, 1.9, 0.2, 61.0], [5.1, 3.8, 1.5, 0.3, 29.0], [5.2, 4.1, 1.5, 0.1, 84.0]]
# 父节点：[ 5.1  3.8  1.5  0.3 29. ]
# 左子树: [[4.8, 3.4, 1.9, 0.2, 61.0]]
# 右子树: [[5.2, 4.1, 1.5, 0.1, 84.0]]
# ============
# 当前待划分样本点：[[4.8, 3.4, 1.9, 0.2, 61.0]]
# 父节点：[ 4.8  3.4  1.9  0.2 61. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.2, 4.1, 1.5, 0.1, 84.0]]
# 父节点：[ 5.2  4.1  1.5  0.1 84. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.4, 3.7, 1.5, 0.2, 83.0], [5.7, 3.8, 1.7, 0.3, 79.0]]
# 父节点：[ 5.7  3.8  1.7  0.3 79. ]
# 左子树: [[5.4, 3.7, 1.5, 0.2, 83.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.4, 3.7, 1.5, 0.2, 83.0]]
# 父节点：[ 5.4  3.7  1.5  0.2 83. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.0, 3.4, 1.6, 0.4, 96.0], [5.0, 3.5, 1.6, 0.6, 74.0], [5.1, 3.8, 1.9, 0.4, 4.0], [5.1, 3.3, 1.7, 0.5, 21.0], [5.4, 3.9, 1.7, 0.4, 1.0]]
# 父节点：[5.1 3.8 1.9 0.4 4. ]
# 左子树: [[5.0, 3.4, 1.6, 0.4, 96.0], [5.0, 3.5, 1.6, 0.6, 74.0]]
# 右子树: [[5.1, 3.3, 1.7, 0.5, 21.0], [5.4, 3.9, 1.7, 0.4, 1.0]]
# ============
# 当前待划分样本点：[[5.0, 3.4, 1.6, 0.4, 96.0], [5.0, 3.5, 1.6, 0.6, 74.0]]
# 父节点：[ 5.   3.5  1.6  0.6 74. ]
# 左子树: [[5.0, 3.4, 1.6, 0.4, 96.0]]
# 右子树: []
# ============
# 当前待划分样本点：[
# 左子树: [[6.0, 2.2, 4.0, 1.0, 9.0], [5.8, 2.7, 3.9, 1.2, 41.0], [6.1, 2.8, 4.0, 1.3, 99.0], [6.2, 2.9, 4.3, 1.3, 15.0], [6.3, 2.3, 4.4, 1.3, 23.0], [6.6, 3.0, 4.4, 1.4, 101.0]]
# 右子树: [[6.1, 2.9, 4.7, 1.4, 63.0], [5.9, 3.0, 4.2, 1.5, 87.0], [6.2, 2.2, 4.5, 1.5, 22.0], [6.0, 2.9, 4.5, 1.5, 62.0], [6.5, 2.8, 4.6, 1.5, 19.0], [6.2, 2.8, 4.8, 1.8, 64.0]]
# ============
# 当前待划分样本点：[[5.8, 2.7, 3.9, 1.2, 41.0], [6.0, 2.2, 4.0, 1.0, 9.0], [6.1, 2.8, 4.0, 1.3, 99.0], [6.2, 2.9, 4.3, 1.3, 15.0], [6.3, 2.3, 4.4, 1.3, 23.0], [6.6, 3.0, 4.4, 1.4, 101.0]]
# 父节点：[ 6.2  2.9  4.3  1.3 15. ]
# 左子树: [[5.8, 2.7, 3.9, 1.2, 41.0], [6.0, 2.2, 4.0, 1.0, 9.0], [6.1, 2.8, 4.0, 1.3, 99.0]]
# 右子树: [[6.3, 2.3, 4.4, 1.3, 23.0], [6.6, 3.0, 4.4, 1.4, 101.0]]
# ============
# 当前待划分样本点：[[6.0, 2.2, 4.0, 1.0, 9.0], [5.8, 2.7, 3.9, 1.2, 41.0], [6.1, 2.8, 4.0, 1.3, 99.0]]
# 父节点：[ 5.8  2.7  3.9  1.2 41. ]
# 左子树: [[6.0, 2.2, 4.0, 1.0, 9.0]]
# 右子树: [[6.1, 2.8, 4.0, 1.3, 99.0]]
# ============
# 当前待划分样本点：[[6.0, 2.2, 4.0, 1.0, 9.0]]
# 父节点：[6.  2.2 4.  1.  9. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.1, 2.8, 4.0, 1.3, 99.0]]
# 父节点：[ 6.1  2.8  4.   1.3 99. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.3, 2.3, 4.4, 1.3, 23.0], [6.6, 3.0, 4.4, 1.4, 101.0]]
# 父节点：[  6.6   3.    4.4   1.4 101. ]
# 左子树: [[6.3, 2.3, 4.4, 1.3, 23.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.3, 2.3, 4.4, 1.3, 23.0]]
# 父节点：[ 6.3  2.3  4.4  1.3 23. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.9, 3.0, 4.2, 1.5, 87.0], [6.0, 2.9, 4.5, 1.5, 62.0], [6.1, 2.9, 4.7, 1.4, 63.0], [6.2, 2.2, 4.5, 1.5, 22.0], [6.2, 2.8, 4.8, 1.8, 64.0], [6.5, 2.8, 4.6, 1.5, 19.0]]
# 父节点：[ 6.2  2.2  4.5  1.5 22. ]
# 左子树: [[5.9, 3.0, 4.2, 1.5, 87.0], [6.0, 2.9, 4.5, 1.5, 62.0], [6.1, 2.9, 4.7, 1.4, 63.0]]
# 右子树: [[6.2, 2.8, 4.8, 1.8, 64.0], [6.5, 2.8, 4.6, 1.5, 19.0]]
# ============
# 当前待划分样本点：[[6.0, 2.9, 4.5, 1.5, 62.0], [6.1, 2.9, 4.7, 1.4, 63.0], [5.9, 3.0, 4.2, 1.5, 87.0]]
# 父节点：[ 6.1  2.9  4.7  1.4 63. ]
# 左子树: [[6.0, 2.9, 4.5, 1.5, 62.0]]
# 右子树: [[5.9, 3.0, 4.2, 1.5, 87.0]]
# ============
# 当前待划分样本点：[[6.0, 2.9, 4.5, 1.5, 62.0]]
# 父节点：[ 6.   2.9  4.5  1.5 62. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.9, 3.0, 4.2, 1.5, 87.0]]
# 父节点：[ 5.9  3.   4.2  1.5 87. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.2, 2.8, 4.8, 1.8, 64.0], [6.5, 2.8, 4.6, 1.5, 19.0]]
# 父节点：[ 6.5  2.8  4.6  1.5 19. ]
# 左子树: [[6.2, 2.8, 4.8, 1.8, 64.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.2, 2.8, 4.8, 1.8, 64.0]]
# 父节点：[ 6.2  2.8  4.8  1.8 64. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.0, 2.7, 5.1, 1.6, 86.0], [6.3, 2.7, 4.9, 1.8, 54.0], [6.1, 3.0, 4.9, 1.8, 57.0], [6.5, 3.0, 5.5, 1.8, 42.0], [6.3, 2.9, 5.6, 1.8, 38.0], [7.3, 2.9, 6.3, 1.8, 82.0], [6.3, 2.5, 5.0, 1.9, 80.0], [5.8, 2.7, 5.1, 1.9, 36.0], [5.8, 2.7, 5.1, 1.9, 93.0], [6.4, 2.8, 5.6, 2.1, 39.0], [6.4, 2.8, 5.6, 2.2, 5.0], [7.7, 2.6, 6.9, 2.3, 98.0]]
# 父节点：[ 6.3  2.5  5.   1.9 80. ]
# 左子树: [[6.0, 2.7, 5.1, 1.6, 86.0], [6.3, 2.7, 4.9, 1.8, 54.0], [6.1, 3.0, 4.9, 1.8, 57.0], [6.5, 3.0, 5.5, 1.8, 42.0], [6.3, 2.9, 5.6, 1.8, 38.0], [7.3, 2.9, 6.3, 1.8, 82.0]]
# 右子树: [[5.8, 2.7, 5.1, 1.9, 36.0], [5.8, 2.7, 5.1, 1.9, 93.0], [6.4, 2.8, 5.6, 2.1, 39.0], [6.4, 2.8, 5.6, 2.2, 5.0], [7.7, 2.6, 6.9, 2.3, 98.0]]
# ============
# 当前待划分样本点：[[6.0, 2.7, 5.1, 1.6, 86.0], [6.1, 3.0, 4.9, 1.8, 57.0], [6.3, 2.7, 4.9, 1.8, 54.0], [6.3, 2.9, 5.6, 1.8, 38.0], [6.5, 3.0, 5.5, 1.8, 42.0], [7.3, 2.9, 6.3, 1.8, 82.0]]
# 父节点：[ 6.3  2.9  5.6  1.8 38. ]
# 左子树: [[6.0, 2.7, 5.1, 1.6, 86.0], [6.1, 3.0, 4.9, 1.8, 57.0], [6.3, 2.7, 4.9, 1.8, 54.0]]
# 右子树: [[6.5, 3.0, 5.5, 1.8, 42.0], [7.3, 2.9, 6.3, 1.8, 82.0]]
# ============
# 当前待划分样本点：[[6.0, 2.7, 5.1, 1.6, 86.0], [6.3, 2.7, 4.9, 1.8, 54.0], [6.1, 3.0, 4.9, 1.8, 57.0]]
# 父节点：[ 6.3  2.7  4.9  1.8 54. ]
# 左子树: [[6.0, 2.7, 5.1, 1.6, 86.0]]
# 右子树: [[6.1, 3.0, 4.9, 1.8, 57.0]]
# ============
# 当前待划分样本点：[[6.0, 2.7, 5.1, 1.6, 86.0]]
# 父节点：[ 6.   2.7  5.1  1.6 86. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.1, 3.0, 4.9, 1.8, 57.0]]
# 父节点：[ 6.1  3.   4.9  1.8 57. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[7.3, 2.9, 6.3, 1.8, 82.0], [6.5, 3.0, 5.5, 1.8, 42.0]]
# 父节点：[ 6.5  3.   5.5  1.8 42. ]
# 左子树: [[7.3, 2.9, 6.3, 1.8, 82.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[7.3, 2.9, 6.3, 1.8, 82.0]]
# 父节点：[ 7.3  2.9  6.3  1.8 82. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.8, 2.7, 5.1, 1.9, 36.0], [5.8, 2.7, 5.1, 1.9, 93.0], [6.4, 2.8, 5.6, 2.1, 39.0], [6.4, 2.8, 5.6, 2.2, 5.0], [7.7, 2.6, 6.9, 2.3, 98.0]]
# 父节点：[ 6.4  2.8  5.6  2.1 39. ]
# 左子树: [[5.8, 2.7, 5.1, 1.9, 36.0], [5.8, 2.7, 5.1, 1.9, 93.0]]
# 右子树: [[6.4, 2.8, 5.6, 2.2, 5.0], [7.7, 2.6, 6.9, 2.3, 98.0]]
# ============
# 当前待划分样本点：[[5.8, 2.7, 5.1, 1.9, 36.0], [5.8, 2.7, 5.1, 1.9, 93.0]]
# 父节点：[ 5.8  2.7  5.1  1.9 93. ]
# 左子树: [[5.8, 2.7, 5.1, 1.9, 36.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[5.8, 2.7, 5.1, 1.9, 36.0]]
# 父节点：[ 5.8  2.7  5.1  1.9 36. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[7.7, 2.6, 6.9, 2.3, 98.0], [6.4, 2.8, 5.6, 2.2, 5.0]]
# 父节点：[6.4 2.8 5.6 2.2 5. ]
# 左子树: [[7.7, 2.6, 6.9, 2.3, 98.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[7.7, 2.6, 6.9, 2.3, 98.0]]
# 父节点：[ 7.7  2.6  6.9  2.3 98. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.8, 4.0, 1.2, 0.2, 49.0], [6.7, 3.1, 4.7, 1.5, 18.0], [5.9, 3.2, 4.8, 1.8, 52.0], [6.9, 3.1, 4.9, 1.5, 51.0], [6.7, 3.0, 5.0, 1.7, 77.0], [6.9, 3.1, 5.1, 2.3, 90.0], [6.5, 3.2, 5.1, 2.0, 85.0], [6.4, 3.2, 5.3, 2.3, 31.0], [6.9, 3.1, 5.4, 2.1, 53.0], [6.2, 3.4, 5.4, 2.3, 6.0], [6.8, 3.0, 5.5, 2.1, 46.0], [6.4, 3.1, 5.5, 1.8, 102.0], [6.7, 3.1, 5.6, 2.4, 73.0], [6.3, 3.4, 5.6, 2.4, 81.0], [6.9, 3.2, 5.7, 2.3, 75.0], [6.7, 3.3, 5.7, 2.5, 68.0], [6.7, 3.3, 5.7, 2.1, 72.0], [7.1, 3.0, 5.9, 2.1, 40.0], [7.2, 3.2, 6.0, 1.8, 67.0], [6.3, 3.3, 6.0, 2.5, 8.0], [7.7, 3.0, 6.1, 2.3, 43.0], [7.2, 3.6, 6.1, 2.5, 44.0], [7.9, 3.8, 6.4, 2.0, 88.0], [7.6, 3.0, 6.6, 2.1, 94.0], [7.7, 3.8, 6.7, 2.2, 60.0]]
# 父节点：[ 6.7  3.1  5.6  2.4 73. ]
# 当前待划分样本点：[[6.4, 3.1, 5.5, 1.8, 102.0], [5.9, 3.2, 4.8, 1.8, 52.0], [5.8, 4.0, 1.2, 0.2, 49.0]]
# 父节点：[ 5.9  3.2  4.8  1.8 52. ]
# 左子树: [[6.4, 3.1, 5.5, 1.8, 102.0]]
# 右子树: [[5.8, 4.0, 1.2, 0.2, 49.0]]
# ============
# 当前待划分样本点：[[6.4, 3.1, 5.5, 1.8, 102.0]]
# 父节点：[  6.4   3.1   5.5   1.8 102. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[5.8, 4.0, 1.2, 0.2, 49.0]]
# 父节点：[ 5.8  4.   1.2  0.2 49. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.7, 3.0, 5.0, 1.7, 77.0], [6.9, 3.1, 4.9, 1.5, 51.0]]
# 父节点：[ 6.9  3.1  4.9  1.5 51. ]
# 左子树: [[6.7, 3.0, 5.0, 1.7, 77.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.7, 3.0, 5.0, 1.7, 77.0]]
# 父节点：[ 6.7  3.   5.   1.7 77. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.2, 3.4, 5.4, 2.3, 6.0], [6.4, 3.2, 5.3, 2.3, 31.0], [6.8, 3.0, 5.5, 2.1, 46.0], [6.9, 3.1, 5.4, 2.1, 53.0], [6.9, 3.1, 5.1, 2.3, 90.0]]
# 父节点：[ 6.8  3.   5.5  2.1 46. ]
# 左子树: [[6.2, 3.4, 5.4, 2.3, 6.0], [6.4, 3.2, 5.3, 2.3, 31.0]]
# 右子树: [[6.9, 3.1, 5.4, 2.1, 53.0], [6.9, 3.1, 5.1, 2.3, 90.0]]
# ============
# 当前待划分样本点：[[6.4, 3.2, 5.3, 2.3, 31.0], [6.2, 3.4, 5.4, 2.3, 6.0]]
# 父节点：[6.2 3.4 5.4 2.3 6. ]
# 左子树: [[6.4, 3.2, 5.3, 2.3, 31.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.4, 3.2, 5.3, 2.3, 31.0]]
# 父节点：[ 6.4  3.2  5.3  2.3 31. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.9, 3.1, 5.4, 2.1, 53.0], [6.9, 3.1, 5.1, 2.3, 90.0]]
# 父节点：[ 6.9  3.1  5.1  2.3 90. ]
# 左子树: [[6.9, 3.1, 5.4, 2.1, 53.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.9, 3.1, 5.4, 2.1, 53.0]]
# 父节点：[ 6.9  3.1  5.4  2.1 53. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[7.2, 3.2, 6.0, 1.8, 67.0], [7.9, 3.8, 6.4, 2.0, 88.0], [6.7, 3.3, 5.7, 2.1, 72.0], [7.1, 3.0, 5.9, 2.1, 40.0], [7.6, 3.0, 6.6, 2.1, 94.0], [7.7, 3.8, 6.7, 2.2, 60.0], [6.9, 3.2, 5.7, 2.3, 75.0], [7.7, 3.0, 6.1, 2.3, 43.0], [6.3, 3.4, 5.6, 2.4, 81.0], [6.7, 3.3, 5.7, 2.5, 68.0], [6.3, 3.3, 6.0, 2.5, 8.0], [7.2, 3.6, 6.1, 2.5, 44.0]]
# 父节点：[ 6.9  3.2  5.7  2.3 75. ]
# 左子树: [[7.2, 3.2, 6.0, 1.8, 67.0], [7.9, 3.8, 6.4, 2.0, 88.0], [6.7, 3.3, 5.7, 2.1, 72.0], [7.1, 3.0, 5.9, 2.1, 40.0], [7.6, 3.0, 6.6, 2.1, 94.0], [7.7, 3.8, 6.7, 2.2, 60.0]]
# 右子树: [[7.7, 3.0, 6.1, 2.3, 43.0], [6.3, 3.4, 5.6, 2.4, 81.0], [6.7, 3.3, 5.7, 2.5, 68.0], [6.3, 3.3, 6.0, 2.5, 8.0], [7.2, 3.6, 6.1, 2.5, 44.0]]
# ============
# 当前待划分样本点：[[6.7, 3.3, 5.7, 2.1, 72.0], [7.1, 3.0, 5.9, 2.1, 40.0], [7.2, 3.2, 6.0, 1.8, 67.0], [7.6, 3.0, 6.6, 2.1, 94.0], [7.7, 3.8, 6.7, 2.2, 60.0], [7.9, 3.8, 6.4, 2.0, 88.0]]
# 父节点：[ 7.6  3.   6.6  2.1 94. ]
# 左子树: [[6.7, 3.3, 5.7, 2.1, 72.0], [7.1, 3.0, 5.9, 2.1, 40.0], [7.2, 3.2, 6.0, 1.8, 67.0]]
# 右子树: [[7.7, 3.8, 6.7, 2.2, 60.0], [7.9, 3.8, 6.4, 2.0, 88.0]]
# ============
# 当前待划分样本点：[[7.1, 3.0, 5.9, 2.1, 40.0], [7.2, 3.2, 6.0, 1.8, 67.0], [6.7, 3.3, 5.7, 2.1, 72.0]]
# 父节点：[ 7.2  3.2  6.   1.8 67. ]
# 左子树: [[7.1, 3.0, 5.9, 2.1, 40.0]]
# 右子树: [[6.7, 3.3, 5.7, 2.1, 72.0]]
# ============
# 当前待划分样本点：[[7.1, 3.0, 5.9, 2.1, 40.0]]
# 父节点：[ 7.1  3.   5.9  2.1 40. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.7, 3.3, 5.7, 2.1, 72.0]]
# 父节点：[ 6.7  3.3  5.7  2.1 72. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[7.7, 3.8, 6.7, 2.2, 60.0], [7.9, 3.8, 6.4, 2.0, 88.0]]
# 父节点：[ 7.9  3.8  6.4  2.  88. ]
# 左子树: [[7.7, 3.8, 6.7, 2.2, 60.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[7.7, 3.8, 6.7, 2.2, 60.0]]
# 父节点：[ 7.7  3.8  6.7  2.2 60. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[6.3, 3.4, 5.6, 2.4, 81.0], [6.3, 3.3, 6.0, 2.5, 8.0], [6.7, 3.3, 5.7, 2.5, 68.0], [7.2, 3.6, 6.1, 2.5, 44.0], [7.7, 3.0, 6.1, 2.3, 43.0]]
# 父节点：[ 6.7  3.3  5.7  2.5 68. ]
# 左子树: [[6.3, 3.4, 5.6, 2.4, 81.0], [6.3, 3.3, 6.0, 2.5, 8.0]]
# 右子树: [[7.2, 3.6, 6.1, 2.5, 44.0], [7.7, 3.0, 6.1, 2.3, 43.0]]
# ============
# 当前待划分样本点：[[6.3, 3.3, 6.0, 2.5, 8.0], [6.3, 3.4, 5.6, 2.4, 81.0]]
# 父节点：[ 6.3  3.4  5.6  2.4 81. ]
# 左子树: [[6.3, 3.3, 6.0, 2.5, 8.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[6.3, 3.3, 6.0, 2.5, 8.0]]
# 父节点：[6.3 3.3 6.  2.5 8. ]
# 左子树: []
# 右子树: []
# ============
# 当前待划分样本点：[[7.7, 3.0, 6.1, 2.3, 43.0], [7.2, 3.6, 6.1, 2.5, 44.0]]
# 父节点：[ 7.2  3.6  6.1  2.5 44. ]
# 左子树: [[7.7, 3.0, 6.1, 2.3, 43.0]]
# 右子树: []
# ============
# 当前待划分样本点：[[7.7, 3.0, 6.1, 2.3, 43.0]]
# 父节点：[ 7.7  3.   6.1  2.3 43. ]
# 左子树: []
# 右子树: []
# ============
#
#
# =========== 正在查找离样本点[4.6 3.2 1.4 0.2]最近的5个样本点！==========
#
# K近邻搜索当前访问节点为：data([5.8 2.6 4.  1.2]),index(16)
# 	有序列表中的节点数目为：0 < 5，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([5.8 2.6 4.  1.2]),index(16)
#
#
# 访问当前节点data([5.8 2.6 4.  1.2]),index(16)的左孩子
# K近邻搜索当前访问节点为：data([4.7 3.2 1.6 0.2]),index(66)
# 	有序列表中的节点数目为：1 < 5，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.8 2.6 4.  1.2]),index(16)
#
#
# 访问当前节点data([4.7 3.2 1.6 0.2]),index(66)的右孩子
# K近邻搜索当前访问节点为：data([5.2 3.5 1.5 0.2]),index(47)
# 	有序列表中的节点数目为：2 < 5，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.2 3.5 1.5 0.2]),index(47)
# 			data([5.8 2.6 4.  1.2]),index(16)
#
#
# 访问当前节点data([5.2 3.5 1.5 0.2]),index(47)的左孩子
# K近邻搜索当前访问节点为：data([5.1 3.4 1.5 0.2]),index(13)
# 	有序列表中的节点数目为：3 < 5，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.1 3.4 1.5 0.2]),index(13)
# 			data([5.2 3.5 1.5 0.2]),index(47)
# 			data([5.8 2.6 4.  1.2]),index(16)
#
#
# 访问当前节点data([5.1 3.4 1.5 0.2]),index(13)的右孩子
# K近邻搜索当前访问节点为：data([5.1 3.5 1.4 0.3]),index(76)
# 	有序列表中的节点数目为：4 < 5，直接加入新节点并排序
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.1 3.4 1.5 0.2]),index(13)
# 			data([5.1 3.5 1.4 0.3]),index(76)
# 			data([5.2 3.5 1.5 0.2]),index(47)
# 			data([5.8 2.6 4.  1.2]),index(16)
#
#
# 访问当前节点data([5.1 3.5 1.4 0.3]),index(76)的左孩子
# K近邻搜索当前访问节点为：data([5.  3.5 1.3 0.3]),index(97)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.8 2.6 4.  1.2]),index(16)的距离为 3.092
# 	当前节点到被搜索点的距离0.52 < 被搜索点到列表中最后一个节点的距离3.092，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.  3.5 1.3 0.3]),index(97)
# 			data([5.1 3.4 1.5 0.2]),index(13)
# 			data([5.1 3.5 1.4 0.3]),index(76)
# 			data([5.2 3.5 1.5 0.2]),index(47)
#
#
# 访问当前节点data([5.  3.5 1.3 0.3]),index(97)的左孩子
# K近邻搜索当前访问节点为：data([4.6 3.4 1.4 0.3]),index(91)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([4.6 3.4 1.4 0.3]),index(91)的距离为 0.224
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.2 3.5 1.5 0.2]),index(47)的距离为 0.678
# 	当前节点到被搜索点的距离0.224 < 被搜索点到列表中最后一个节点的距离0.678，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.6 3.4 1.4 0.3]),index(91)
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.  3.5 1.3 0.3]),index(97)
# 			data([5.1 3.4 1.5 0.2]),index(13)
# 			data([5.1 3.5 1.4 0.3]),index(76)
#
#
# 访问当前节点data([4.6 3.4 1.4 0.3]),index(91)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([4.6 3.4 1.4 0.3]),index(91)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.4 - 1.4| < 0.592 **
# 访问当前节点data([4.6 3.4 1.4 0.3]),index(91)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.  3.5 1.3 0.3]),index(97)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.5 - 3.2| < 0.592 **
# 访问当前节点data([5.  3.5 1.3 0.3]),index(97)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.1 3.5 1.4 0.3]),index(76)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |5.1 - 4.6| < 0.592 **
# 访问当前节点data([5.1 3.5 1.4 0.3]),index(76)的右孩子
# K近邻搜索当前访问节点为：data([5.4 3.9 1.3 0.4]),index(95)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.4 3.9 1.3 0.4]),index(95)的距离为 1.086
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.1 3.5 1.4 0.3]),index(76)的距离为 0.592
# 访问当前节点data([5.4 3.9 1.3 0.4]),index(95)的左孩子
# K近邻搜索当前访问节点为：data([5.4 3.4 1.5 0.4]),index(7)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.4 3.4 1.5 0.4]),index(7)的距离为 0.854
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.1 3.5 1.4 0.3]),index(76)的距离为 0.592
# 访问当前节点data([5.4 3.4 1.5 0.4]),index(7)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.4 3.4 1.5 0.4]),index(7)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.5 - 1.4| < 0.592 **
# 访问当前节点data([5.4 3.4 1.5 0.4]),index(7)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.4 3.9 1.3 0.4]),index(95)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.1 3.4 1.5 0.2]),index(13)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |0.2 - 0.2| < 0.592 **
# 访问当前节点data([5.1 3.4 1.5 0.2]),index(13)的左孩子
# K近邻搜索当前访问节点为：data([5.  3.4 1.5 0.2]),index(92)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.  3.4 1.5 0.2]),index(92)的距离为 0.458
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.1 3.5 1.4 0.3]),index(76)的距离为 0.592
# 	当前节点到被搜索点的距离0.458 < 被搜索点到列表中最后一个节点的距离0.592，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.6 3.4 1.4 0.3]),index(91)
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.  3.4 1.5 0.2]),index(92)
# 			data([5.  3.5 1.3 0.3]),index(97)
# 			data([5.1 3.4 1.5 0.2]),index(13)
#
#
# 访问当前节点data([5.  3.4 1.5 0.2]),index(92)的左孩子
# K近邻搜索当前访问节点为：data([4.6 3.6 1.  0.2]),index(100)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([4.6 3.6 1.  0.2]),index(100)的距离为 0.566
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.1 3.4 1.5 0.2]),index(13)的距离为 0.548
# 访问当前节点data([4.6 3.6 1.  0.2]),index(100)的左孩子
# K近邻搜索当前访问节点为：data([5.  3.3 1.4 0.2]),index(2)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.  3.3 1.4 0.2]),index(2)的距离为 0.412
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.1 3.4 1.5 0.2]),index(13)的距离为 0.548
# 	当前节点到被搜索点的距离0.412 < 被搜索点到列表中最后一个节点的距离0.548，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([4.6 3.4 1.4 0.3]),index(91)
# 			data([4.7 3.2 1.6 0.2]),index(66)
# 			data([5.  3.3 1.4 0.2]),index(2)
# 			data([5.  3.4 1.5 0.2]),index(92)
# 			data([5.  3.5 1.3 0.3]),index(97)
#
#
# 访问当前节点data([5.  3.3 1.4 0.2]),index(2)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.  3.3 1.4 0.2]),index(2)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.4 - 1.4| < 0.52 **
# 访问当前节点data([5.  3.3 1.4 0.2]),index(2)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([4.6 3.6 1.  0.2]),index(100)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.6 - 3.2| < 0.52 **
# 访问当前节点data([4.6 3.6 1.  0.2]),index(100)的右孩子
# K近邻搜索当前访问节点为：data([5.  3.6 1.4 0.2]),index(48)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.  3.6 1.4 0.2]),index(48)的距离为 0.566
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.  3.6 1.4 0.2]),index(48)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.  3.6 1.4 0.2]),index(48)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.4 - 1.4| < 0.52 **
# 访问当前节点data([5.  3.6 1.4 0.2]),index(48)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.  3.4 1.5 0.2]),index(92)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |5.0 - 4.6| < 0.52 **
# 访问当前节点data([5.  3.4 1.5 0.2]),index(92)的右孩子
# K近邻搜索当前访问节点为：data([5.5 4.2 1.4 0.2]),index(58)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.5 4.2 1.4 0.2]),index(58)的距离为 1.345
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.5 4.2 1.4 0.2]),index(58)的左孩子
# K近邻搜索当前访问节点为：data([5.5 3.5 1.3 0.2]),index(32)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.5 3.5 1.3 0.2]),index(32)的距离为 0.954
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.5 3.5 1.3 0.2]),index(32)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.5 3.5 1.3 0.2]),index(32)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.3 - 1.4| < 0.52 **
# 访问当前节点data([5.5 3.5 1.3 0.2]),index(32)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.5 4.2 1.4 0.2]),index(58)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.2 3.5 1.5 0.2]),index(47)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.5 - 1.4| < 0.52 **
# 访问当前节点data([5.2 3.5 1.5 0.2]),index(47)的右孩子
# K近邻搜索当前访问节点为：data([5.7 4.4 1.5 0.4]),index(103)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.7 4.4 1.5 0.4]),index(103)的距离为 1.643
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.7 4.4 1.5 0.4]),index(103)的左孩子
# K近邻搜索当前访问节点为：data([5.3 3.7 1.5 0.2]),index(30)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.3 3.7 1.5 0.2]),index(30)的距离为 0.866
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.3 3.7 1.5 0.2]),index(30)的左孩子
# K近邻搜索当前访问节点为：data([5.1 3.8 1.5 0.3]),index(29)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.1 3.8 1.5 0.3]),index(29)的距离为 0.794
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.1 3.8 1.5 0.3]),index(29)的左孩子
# K近邻搜索当前访问节点为：data([4.8 3.4 1.9 0.2]),index(61)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([4.8 3.4 1.9 0.2]),index(61)的距离为 0.574
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([4.8 3.4 1.9 0.2]),index(61)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([4.8 3.4 1.9 0.2]),index(61)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.9 - 1.4| < 0.52 **
# 访问当前节点data([4.8 3.4 1.9 0.2]),index(61)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.1 3.8 1.5 0.3]),index(29)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.3 3.7 1.5 0.2]),index(30)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.7 4.4 1.5 0.4]),index(103)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |0.4 - 0.2| < 0.52 **
# 访问当前节点data([5.7 4.4 1.5 0.4]),index(103)的右孩子
# K近邻搜索当前访问节点为：data([5.1 3.8 1.9 0.4]),index(4)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.1 3.8 1.9 0.4]),index(4)的距离为 0.949
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.1 3.8 1.9 0.4]),index(4)的左孩子
# K近邻搜索当前访问节点为：data([5.  3.5 1.6 0.6]),index(74)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.  3.5 1.6 0.6]),index(74)的距离为 0.671
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.  3.5 1.6 0.6]),index(74)的左孩子
# K近邻搜索当前访问节点为：data([5.  3.4 1.6 0.4]),index(96)
# 	被搜索点[4.6 3.2 1.4 0.2]到当前节点data([5.  3.4 1.6 0.4]),index(96)的距离为 0.529
# 	被搜索点[4.6 3.2 1.4 0.2]到列表中最后一个节点data([5.  3.5 1.3 0.3]),index(97)的距离为 0.52
# 访问当前节点data([5.  3.4 1.6 0.4]),index(96)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.  3.4 1.6 0.4]),index(96)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.6 - 1.4| < 0.52 **
# 访问当前节点data([5.  3.4 1.6 0.4]),index(96)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.  3.5 1.6 0.6]),index(74)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.5 - 3.2| < 0.52 **
# ...
# 			data([6.7 3.  5.2 2.3]),index(50)
# 			data([5.8 2.6 4.  1.2]),index(16)
# 			data([6.7 3.1 5.6 2.4]),index(73)
#
#
# 访问当前节点data([6.7 3.1 4.7 1.5]),index(18)的左孩子
# K近邻搜索当前访问节点为：data([5.9 3.2 4.8 1.8]),index(52)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([5.9 3.2 4.8 1.8]),index(52)的距离为 0.469
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.7 3.1 5.6 2.4]),index(73)的距离为 1.285
# 	当前节点到被搜索点的距离0.469 < 被搜索点到列表中最后一个节点的距离1.285，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.5 3.2 5.1 2. ]),index(85)
# 			data([6.7 3.  5.2 2.3]),index(50)
# 			data([5.8 2.6 4.  1.2]),index(16)
#
#
# 访问当前节点data([5.9 3.2 4.8 1.8]),index(52)的右孩子
# K近邻搜索当前访问节点为：data([5.8 4.  1.2 0.2]),index(49)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([5.8 4.  1.2 0.2]),index(49)的距离为 3.867
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([5.8 2.6 4.  1.2]),index(16)的距离为 1.179
# 访问当前节点data([5.8 4.  1.2 0.2]),index(49)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.8 4.  1.2 0.2]),index(49)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.9 3.2 4.8 1.8]),index(52)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.2 - 3.3| < 1.179 **
# 访问当前节点data([5.9 3.2 4.8 1.8]),index(52)的左孩子
# K近邻搜索当前访问节点为：data([6.4 3.1 5.5 1.8]),index(102)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.4 3.1 5.5 1.8]),index(102)的距离为 0.854
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([5.8 2.6 4.  1.2]),index(16)的距离为 1.179
# 	当前节点到被搜索点的距离0.854 < 被搜索点到列表中最后一个节点的距离1.179，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.5 3.2 5.1 2. ]),index(85)
# 			data([6.4 3.1 5.5 1.8]),index(102)
# 			data([6.7 3.  5.2 2.3]),index(50)
#
#
# 访问当前节点data([6.4 3.1 5.5 1.8]),index(102)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.4 3.1 5.5 1.8]),index(102)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |5.5 - 4.7| < 0.995 **
# 访问当前节点data([6.4 3.1 5.5 1.8]),index(102)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.7 3.1 4.7 1.5]),index(18)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |6.7 - 6.3| < 0.995 **
# 访问当前节点data([6.7 3.1 4.7 1.5]),index(18)的右孩子
# K近邻搜索当前访问节点为：data([6.9 3.1 4.9 1.5]),index(51)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.7 3.  5.2 2.3]),index(50)的距离为 0.995
# 	当前节点到被搜索点的距离0.671 < 被搜索点到列表中最后一个节点的距离0.995，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.5 3.2 5.1 2. ]),index(85)
# 			data([6.9 3.1 4.9 1.5]),index(51)
# 			data([6.4 3.1 5.5 1.8]),index(102)
#
#
# 访问当前节点data([6.9 3.1 4.9 1.5]),index(51)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.9 3.1 4.9 1.5]),index(51)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.1 - 3.3| < 0.854 **
# 访问当前节点data([6.9 3.1 4.9 1.5]),index(51)的左孩子
# K近邻搜索当前访问节点为：data([6.7 3.  5.  1.7]),index(77)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.7 3.  5.  1.7]),index(77)的距离为 0.592
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.4 3.1 5.5 1.8]),index(102)的距离为 0.854
# 	当前节点到被搜索点的距离0.592 < 被搜索点到列表中最后一个节点的距离0.854，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.7 3.  5.  1.7]),index(77)
# 			data([6.5 3.2 5.1 2. ]),index(85)
# 			data([6.9 3.1 4.9 1.5]),index(51)
#
#
# 访问当前节点data([6.7 3.  5.  1.7]),index(77)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.7 3.  5.  1.7]),index(77)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |5.0 - 4.7| < 0.671 **
# 访问当前节点data([6.7 3.  5.  1.7]),index(77)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.5 3.2 5.1 2. ]),index(85)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |2.0 - 1.6| < 0.671 **
# 访问当前节点data([6.5 3.2 5.1 2. ]),index(85)的右孩子
# K近邻搜索当前访问节点为：data([6.8 3.  5.5 2.1]),index(46)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.8 3.  5.5 2.1]),index(46)的距离为 1.109
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 访问当前节点data([6.8 3.  5.5 2.1]),index(46)的左孩子
# K近邻搜索当前访问节点为：data([6.2 3.4 5.4 2.3]),index(6)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.2 3.4 5.4 2.3]),index(6)的距离为 1.0
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 访问当前节点data([6.2 3.4 5.4 2.3]),index(6)的左孩子
# K近邻搜索当前访问节点为：data([6.4 3.2 5.3 2.3]),index(31)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.4 3.2 5.3 2.3]),index(31)的距离为 0.933
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 访问当前节点data([6.4 3.2 5.3 2.3]),index(31)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.4 3.2 5.3 2.3]),index(31)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |5.3 - 4.7| < 0.671 **
# 访问当前节点data([6.4 3.2 5.3 2.3]),index(31)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.2 3.4 5.4 2.3]),index(6)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.4 - 3.3| < 0.671 **
# 访问当前节点data([6.2 3.4 5.4 2.3]),index(6)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.8 3.  5.5 2.1]),index(46)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |6.8 - 6.3| < 0.671 **
# 访问当前节点data([6.8 3.  5.5 2.1]),index(46)的右孩子
# K近邻搜索当前访问节点为：data([6.9 3.1 5.1 2.3]),index(90)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.9 3.1 5.1 2.3]),index(90)的距离为 1.025
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 访问当前节点data([6.9 3.1 5.1 2.3]),index(90)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.9 3.1 5.1 2.3]),index(90)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.1 - 3.3| < 0.671 **
# 访问当前节点data([6.9 3.1 5.1 2.3]),index(90)的左孩子
# K近邻搜索当前访问节点为：data([6.9 3.1 5.4 2.1]),index(53)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.9 3.1 5.4 2.1]),index(53)的距离为 1.068
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 访问当前节点data([6.9 3.1 5.4 2.1]),index(53)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.9 3.1 5.4 2.1]),index(53)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.7 3.1 5.6 2.4]),index(73)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.7 3.  5.2 2.3]),index(50)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.0 - 3.3| < 0.671 **
# 访问当前节点data([6.7 3.  5.2 2.3]),index(50)的左孩子
# K近邻搜索当前访问节点为：data([6.  3.  4.8 1.8]),index(35)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.  3.  4.8 1.8]),index(35)的距离为 0.48
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.9 3.1 4.9 1.5]),index(51)的距离为 0.671
# 	当前节点到被搜索点的距离0.48 < 被搜索点到列表中最后一个节点的距离0.671，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.  3.  4.8 1.8]),index(35)
# 			data([6.7 3.  5.  1.7]),index(77)
# 			data([6.5 3.2 5.1 2. ]),index(85)
#
#
# 访问当前节点data([6.  3.  4.8 1.8]),index(35)的左孩子
# K近邻搜索当前访问节点为：data([6.1 3.  4.6 1.4]),index(28)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.1 3.  4.6 1.4]),index(28)的距离为 0.424
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.5 3.2 5.1 2. ]),index(85)的距离为 0.608
# 	当前节点到被搜索点的距离0.424 < 被搜索点到列表中最后一个节点的距离0.608，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.1 3.  4.6 1.4]),index(28)
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.  3.  4.8 1.8]),index(35)
# 			data([6.7 3.  5.  1.7]),index(77)
#
#
# 访问当前节点data([6.1 3.  4.6 1.4]),index(28)的右孩子
# K近邻搜索当前访问节点为：data([6.2 2.2 4.5 1.5]),index(22)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.2 2.2 4.5 1.5]),index(22)的距离为 1.127
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.7 3.  5.  1.7]),index(77)的距离为 0.592
# 访问当前节点data([6.2 2.2 4.5 1.5]),index(22)的右孩子
# K近邻搜索当前访问节点为：data([6.5 2.8 4.6 1.5]),index(19)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.5 2.8 4.6 1.5]),index(19)的距离为 0.557
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.7 3.  5.  1.7]),index(77)的距离为 0.592
# 	当前节点到被搜索点的距离0.557 < 被搜索点到列表中最后一个节点的距离0.592，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.1 3.  4.6 1.4]),index(28)
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.  3.  4.8 1.8]),index(35)
# 			data([6.5 2.8 4.6 1.5]),index(19)
#
#
# 访问当前节点data([6.5 2.8 4.6 1.5]),index(19)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.5 2.8 4.6 1.5]),index(19)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |2.8 - 3.3| < 0.557 **
# 访问当前节点data([6.5 2.8 4.6 1.5]),index(19)的左孩子
# K近邻搜索当前访问节点为：data([6.2 2.8 4.8 1.8]),index(64)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.2 2.8 4.8 1.8]),index(64)的距离为 0.557
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.5 2.8 4.6 1.5]),index(19)的距离为 0.557
# 	当前节点到被搜索点的距离0.557 < 被搜索点到列表中最后一个节点的距离0.557，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.1 3.  4.6 1.4]),index(28)
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.  3.  4.8 1.8]),index(35)
# 			data([6.2 2.8 4.8 1.8]),index(64)
#
#
# 访问当前节点data([6.2 2.8 4.8 1.8]),index(64)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.2 2.8 4.8 1.8]),index(64)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |4.8 - 4.7| < 0.557 **
# 访问当前节点data([6.2 2.8 4.8 1.8]),index(64)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.2 2.2 4.5 1.5]),index(22)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |6.2 - 6.3| < 0.557 **
# 访问当前节点data([6.2 2.2 4.5 1.5]),index(22)的左孩子
# K近邻搜索当前访问节点为：data([6.1 2.9 4.7 1.4]),index(63)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.2 2.8 4.8 1.8]),index(64)的距离为 0.557
# 	当前节点到被搜索点的距离0.49 < 被搜索点到列表中最后一个节点的距离0.557，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.1 3.  4.6 1.4]),index(28)
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.  3.  4.8 1.8]),index(35)
# 			data([6.1 2.9 4.7 1.4]),index(63)
#
#
# 访问当前节点data([6.1 2.9 4.7 1.4]),index(63)的右孩子
# K近邻搜索当前访问节点为：data([5.9 3.  4.2 1.5]),index(87)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([5.9 3.  4.2 1.5]),index(87)的距离为 0.714
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([5.9 3.  4.2 1.5]),index(87)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.9 3.  4.2 1.5]),index(87)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.1 2.9 4.7 1.4]),index(63)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |2.9 - 3.3| < 0.49 **
# 访问当前节点data([6.1 2.9 4.7 1.4]),index(63)的左孩子
# K近邻搜索当前访问节点为：data([6.  2.9 4.5 1.5]),index(62)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.  2.9 4.5 1.5]),index(62)的距离为 0.548
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.  2.9 4.5 1.5]),index(62)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.  2.9 4.5 1.5]),index(62)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |4.5 - 4.7| < 0.49 **
# 访问当前节点data([6.  2.9 4.5 1.5]),index(62)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.1 3.  4.6 1.4]),index(28)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.4 - 1.6| < 0.49 **
# 访问当前节点data([6.1 3.  4.6 1.4]),index(28)的左孩子
# K近邻搜索当前访问节点为：data([6.2 2.9 4.3 1.3]),index(15)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.2 2.9 4.3 1.3]),index(15)的距离为 0.648
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.2 2.9 4.3 1.3]),index(15)的右孩子
# K近邻搜索当前访问节点为：data([6.6 3.  4.4 1.4]),index(101)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.6 3.  4.4 1.4]),index(101)的距离为 0.557
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.6 3.  4.4 1.4]),index(101)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.6 3.  4.4 1.4]),index(101)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.0 - 3.3| < 0.49 **
# 访问当前节点data([6.6 3.  4.4 1.4]),index(101)的左孩子
# K近邻搜索当前访问节点为：data([6.3 2.3 4.4 1.3]),index(23)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.3 2.3 4.4 1.3]),index(23)的距离为 1.086
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.3 2.3 4.4 1.3]),index(23)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.3 2.3 4.4 1.3]),index(23)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |4.4 - 4.7| < 0.49 **
# 访问当前节点data([6.3 2.3 4.4 1.3]),index(23)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.2 2.9 4.3 1.3]),index(15)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |6.2 - 6.3| < 0.49 **
# 访问当前节点data([6.2 2.9 4.3 1.3]),index(15)的左孩子
# K近邻搜索当前访问节点为：data([5.8 2.7 3.9 1.2]),index(41)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([5.8 2.7 3.9 1.2]),index(41)的距离为 1.187
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([5.8 2.7 3.9 1.2]),index(41)的右孩子
# K近邻搜索当前访问节点为：data([6.1 2.8 4.  1.3]),index(99)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.1 2.8 4.  1.3]),index(99)的距离为 0.933
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.1 2.8 4.  1.3]),index(99)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.1 2.8 4.  1.3]),index(99)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.8 2.7 3.9 1.2]),index(41)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.  3.  4.8 1.8]),index(35)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |4.8 - 4.7| < 0.49 **
# 访问当前节点data([6.  3.  4.8 1.8]),index(35)的右孩子
# K近邻搜索当前访问节点为：data([6.3 2.5 5.  1.9]),index(80)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.3 2.5 5.  1.9]),index(80)的距离为 0.906
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.3 2.5 5.  1.9]),index(80)的左孩子
# K近邻搜索当前访问节点为：data([6.3 2.9 5.6 1.8]),index(38)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.3 2.9 5.6 1.8]),index(38)的距离为 1.005
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.3 2.9 5.6 1.8]),index(38)的右孩子
# K近邻搜索当前访问节点为：data([6.5 3.  5.5 1.8]),index(42)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.5 3.  5.5 1.8]),index(42)的距离为 0.9
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.5 3.  5.5 1.8]),index(42)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.5 3.  5.5 1.8]),index(42)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |3.0 - 3.3| < 0.49 **
# 访问当前节点data([6.5 3.  5.5 1.8]),index(42)的左孩子
# K近邻搜索当前访问节点为：data([7.3 2.9 6.3 1.8]),index(82)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([7.3 2.9 6.3 1.8]),index(82)的距离为 1.939
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([7.3 2.9 6.3 1.8]),index(82)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([7.3 2.9 6.3 1.8]),index(82)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.3 2.9 5.6 1.8]),index(38)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |6.3 - 6.3| < 0.49 **
# 访问当前节点data([6.3 2.9 5.6 1.8]),index(38)的左孩子
# K近邻搜索当前访问节点为：data([6.3 2.7 4.9 1.8]),index(54)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.3 2.7 4.9 1.8]),index(54)的距离为 0.663
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 访问当前节点data([6.3 2.7 4.9 1.8]),index(54)的右孩子
# K近邻搜索当前访问节点为：data([6.1 3.  4.9 1.8]),index(57)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.1 3.  4.9 1.8]),index(57)的距离为 0.458
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.1 2.9 4.7 1.4]),index(63)的距离为 0.49
# 	当前节点到被搜索点的距离0.458 < 被搜索点到列表中最后一个节点的距离0.49，进行替换
# 		当前K近邻有序列表中的节点为（已按距离升序排序）：
# 			data([6.1 3.  4.6 1.4]),index(28)
# 			data([6.1 3.  4.9 1.8]),index(57)
# 			data([6.7 3.1 4.7 1.5]),index(18)
# 			data([5.9 3.2 4.8 1.8]),index(52)
# 			data([6.  3.  4.8 1.8]),index(35)
#
#
# 访问当前节点data([6.1 3.  4.9 1.8]),index(57)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.1 3.  4.9 1.8]),index(57)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |4.9 - 4.7| < 0.48 **
# 访问当前节点data([6.1 3.  4.9 1.8]),index(57)的左孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.3 2.7 4.9 1.8]),index(54)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.3 2.5 5.  1.9]),index(80)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |1.9 - 1.6| < 0.48 **
# 访问当前节点data([6.3 2.5 5.  1.9]),index(80)的右孩子
# K近邻搜索当前访问节点为：data([6.4 2.8 5.6 2.1]),index(39)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.4 2.8 5.6 2.1]),index(39)的距离为 1.149
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.  3.  4.8 1.8]),index(35)的距离为 0.48
# 访问当前节点data([6.4 2.8 5.6 2.1]),index(39)的左孩子
# K近邻搜索当前访问节点为：data([5.8 2.7 5.1 1.9]),index(93)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([5.8 2.7 5.1 1.9]),index(93)的距离为 0.927
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.  3.  4.8 1.8]),index(35)的距离为 0.48
# 访问当前节点data([5.8 2.7 5.1 1.9]),index(93)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([5.8 2.7 5.1 1.9]),index(93)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([6.4 2.8 5.6 2.1]),index(39)，开始判断步骤(6)
# ** 被搜索点到当前节点划分维度的距离小于列表中最后一个元素到被搜索点的距离，即 |6.4 - 6.3| < 0.48 **
# 访问当前节点data([6.4 2.8 5.6 2.1]),index(39)的右孩子
# K近邻搜索当前访问节点为：data([6.4 2.8 5.6 2.2]),index(5)
# 	被搜索点[6.3 3.3 4.7 1.6]到当前节点data([6.4 2.8 5.6 2.2]),index(5)的距离为 1.196
# 	被搜索点[6.3 3.3 4.7 1.6]到列表中最后一个节点data([6.  3.  4.8 1.8]),index(35)的距离为 0.48
# 访问当前节点data([6.4 2.8 5.6 2.2]),index(5)的右孩子
# K近邻搜索当前访问节点为：None
# 回到上一层递归，当前访问节点为 data([6.4 2.8 5.6 2.2]),index(5)，开始判断步骤(6)
# 回到上一层递归，当前访问节点为 data([5.8 2.6 4.  1.2]),index(16)，开始判断步骤(6)
# impl_by_ours 准确率：0.9555555555555556
# impl_by_sklearn 准确率：0.9555555555555556
